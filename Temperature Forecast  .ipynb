# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %matplotlib inline

# %%
df = pd.read_excel('temp.xlsx')
df
# Out:
#       station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0 2013-06-30          28.7          21.4    58.255688
# 1         2.0 2013-06-30          31.9          21.6    52.263397
# 2         3.0 2013-06-30          31.6          23.3    48.690479
# 3         4.0 2013-06-30          32.0          23.4    58.239788
# 4         5.0 2013-06-30          31.4          21.9    56.174095
# ...       ...        ...           ...           ...          ...
# 7747     23.0 2017-08-30          23.3          17.1    26.741310
# 7748     24.0 2017-08-30          23.3          17.7    24.040634
# 7749     25.0 2017-08-30          23.2          17.4    22.933014
# 7750      NaN        NaT          20.0          11.3    19.794666
# 7751      NaN        NaT          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.head(5)
# Out:
#    station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0 2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0 2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0 2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0 2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.describe()
# Out:
#            station                 Date  Present_Tmax  Present_Tmin  \
# count  7750.000000                 7750   7682.000000   7682.000000
# mean     13.000000  2015-07-30 21:36:00     29.768211     23.225059
# min       1.000000  2013-06-30 00:00:00     20.000000     11.300000
# 25%       7.000000  2014-07-15 00:00:00     27.800000     21.700000
# 50%      13.000000  2015-07-30 12:00:00     29.900000     23.400000
# 75%      19.000000  2016-08-15 00:00:00     32.000000     24.900000
# max      25.000000  2017-08-30 00:00:00     37.600000     29.900000
# std       7.211568                  NaN      2.969999      2.413961
#
#        LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  \
# count  7677.000000  7677.000000       7677.000000       7677.000000
# mean     56.759372    88.374804         29.613447         23.512589
# min      19.794666    58.936283         17.624954         14.272646
# 25%      45.963543    84.222862         27.673499         22.089739
# ...

# %%
df.isnull().any()
# Out:
# station              True
# Date                 True
# Present_Tmax         True
# Present_Tmin         True
# LDAPS_RHmin          True
# LDAPS_RHmax          True
# LDAPS_Tmax_lapse     True
# LDAPS_Tmin_lapse     True
# LDAPS_WS             True
# LDAPS_LH             True
# LDAPS_CC1            True
# LDAPS_CC2            True
# LDAPS_CC3            True
# LDAPS_CC4            True
# LDAPS_PPT1           True
# LDAPS_PPT2           True
# LDAPS_PPT3           True
# LDAPS_PPT4           True
# lat                 False
# lon                 False
# DEM                 False
# Slope               False
# Solar radiation     False
# Next_Tmax            True
# Next_Tmin            True
# dtype: bool

# %%
df_num= df.loc[:,['station','Date','Present_Tmax','LDAPS_RHmin','LDAPS_RHmax', 'LDAPS_RHmax','LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS','LDAPS_LH','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4','lat','lon','DEM','Slope','Solar radiation','Next_Tmax','Next_Tmin']]
df.head()
# Out:
#    station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0 2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0 2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0 2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0 2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.plot(subplots=True, figsize=(25,20))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >], dtype=object)

# %%
df['2013':'2014'].resample('D').fillna(method='pad').plot(subplots=True, figsize=(25,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df['2013':'2014'].resample('D').fillna(method='pad').plot(subplots=True, figsize=(25,20))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3735, in DataFrame.__getitem__(self, key)
#    3733 # Do we have a slicer (on rows)?
#    3734 if isinstance(key, slice):
# -> 3735     indexer = self.index._convert_slice_indexer(key, kind="getitem")
#    3736     if isinstance(indexer, np.ndarray):
#    3737         # reachable with DatetimeIndex
#    3738         indexer = lib.maybe_indices_to_slice(
#    3739             indexer.astype(np.intp, copy=False), len(self)
#    3740         )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4101, in Index._convert_slice_indexer(self, key, kind)
#    4097 if kind == "getitem":
# ...

# %%
df.hist(bins=10,figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'station'}>,
#         <Axes: title={'center': 'Date'}>,
#         <Axes: title={'center': 'Present_Tmax'}>,
#         <Axes: title={'center': 'Present_Tmin'}>,
#         <Axes: title={'center': 'LDAPS_RHmin'}>],
#        [<Axes: title={'center': 'LDAPS_RHmax'}>,
#         <Axes: title={'center': 'LDAPS_Tmax_lapse'}>,
#         <Axes: title={'center': 'LDAPS_Tmin_lapse'}>,
#         <Axes: title={'center': 'LDAPS_WS'}>,
#         <Axes: title={'center': 'LDAPS_LH'}>],
#        [<Axes: title={'center': 'LDAPS_CC1'}>,
#         <Axes: title={'center': 'LDAPS_CC2'}>,
#         <Axes: title={'center': 'LDAPS_CC3'}>,
#         <Axes: title={'center': 'LDAPS_CC4'}>,
#         <Axes: title={'center': 'LDAPS_PPT1'}>],
#        [<Axes: title={'center': 'LDAPS_PPT2'}>,
#         <Axes: title={'center': 'LDAPS_PPT3'}>,
#         <Axes: title={'center': 'LDAPS_PPT4'}>,
#         <Axes: title={'center': 'lat'}>, <Axes: title={'center': 'lon'}>],
# ...

# %%
df.pop("LDAPS_RHmax")
df
# Out:
#       station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0 2013-06-30          28.7          21.4    58.255688
# 1         2.0 2013-06-30          31.9          21.6    52.263397
# 2         3.0 2013-06-30          31.6          23.3    48.690479
# 3         4.0 2013-06-30          32.0          23.4    58.239788
# 4         5.0 2013-06-30          31.4          21.9    56.174095
# ...       ...        ...           ...           ...          ...
# 7747     23.0 2017-08-30          23.3          17.1    26.741310
# 7748     24.0 2017-08-30          23.3          17.7    24.040634
# 7749     25.0 2017-08-30          23.2          17.4    22.933014
# 7750      NaN        NaT          20.0          11.3    19.794666
# 7751      NaN        NaT          37.6          29.9    98.524734
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0            28.074101         23.006936   6.818887   69.451805   0.233947
# ...

# %%
y=df.pop("LDAPS_Tmax_lapse")
x=df

# %%
df_y=y
df_x=x

# %%
train_X,test_X,train_y,test_y=train_test_split(df_x,df_y,test_size=0.2,random_state=2)

# %%
train_X.shape
# Out:
# (6201, 22)

# %%
train_y.shape
# Out:
# (6201,)

# %%
train_y.head()
# Out:
# 2126    30.132659
# 1367    31.874033
# 819     27.474769
# 3424    25.214982
# 5229    27.319403
# Name: LDAPS_Tmax_lapse, dtype: float64

# %%
plt.scatter(df.LDAPS_WS, df.LDAPS_LH)
plt.xlabel("Minimum Temperature")
plt.ylabel("Temperature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9240\4125050734.py in ?()
# ----> 1 plt.scatter(df.LDAPS_WS, df.LDAPS_LH)
#       2 plt.xlabel("Minimum Temperature")
#       3 plt.ylabel("Temperature")
#       4 plt.show()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'LDAPS_WS'

# %%
plt.scatter(df.DEM, df.LDAPS_Tmax_lapse)
plt.xlabel("Heat Index")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(df.lon, df.LDAPS_Tmax_lapse)
plt.xlabel("Minimum Temperature")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(df.Slope, df.lat)
plt.xlabel("Minimum Temperature")
plt.ylabel("Temperature")
plt.show()

# %%
model=LinearRegression()
model.fit(train_X,train_y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 model=LinearRegression()
# ----> 2 model.fit(train_X,train_y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 678 X, y = self._validate_data(
# ...
